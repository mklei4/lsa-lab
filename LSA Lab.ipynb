# %% [markdown]
# Author: Melanie Klein
#
# Date: 6 February 2017
#
# CSC570R Week 4 Lab: Latent Semantic Analysis

# %%
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
#download stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mmcla\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#download newsgroups dataset
from sklearn.datasets import fetch_20newsgroups
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all', shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
stopset = set(stopwords.words('english'))
stopset.update(['000', '00', '01', '02', '03', '04', '05', 'com', 'edu', 'vb30', 'netcom', 'mail'])

# %%
#Peek at raw data
corpus[0]
# Out:
# "From: writingctr@leo.bsuvc.bsu.edu\nSubject: Re: CUB fever.\nOrganization: Ball State University, Muncie, In - Univ. Computing Svc's\nLines: 21\n\n\nIn article <kingoz.735285670@camelot>, kingoz@camelot.bradley.edu (Orin Roth) writes:\n> \n>    CUB fever is hitting me again. I'm beginning to think they have a \n>    chance this year. (what the heck am i thinking?)\n>    Sorry. Just a moment of incompetence.\n>    I'll be ok. Really. \n>    Orin.\n>    Bradley U.\n> \n> --\n> I'm really a jester in disguise!                                   \nI hear ya!  Then again, we must remember that we are indeed Cub fans, and\nthat the Cubs will eventually blow it.  After all, the Cubs are the easiest\nteam in the National League to root for.  No Pressure.  You know they will\nlose eventually.  Oh well, I suppose we must have faith.  After all, they\ndo look pretty good, and they don't even have Sandberg back yet.  \n\nCUBS IN '93!!!!!\n\nCHA\n"

# %%
#Calculate TF-IDF
vectorizer = TfidfVectorizer(stop_words=stopset, use_idf=True, ngram_range=(1, 3))
X = vectorizer.fit_transform(corpus)

# %%
#TF-IDF Vectorized data
print(X[0])
# Out:
#   (0, 51330)	0.073941735884
#   (0, 187940)	0.073941735884
#   (0, 28990)	0.073941735884
#   (0, 144818)	0.073941735884
#   (0, 62636)	0.073941735884
#   (0, 76423)	0.073941735884
#   (0, 132020)	0.073941735884
#   (0, 101823)	0.073941735884
#   (0, 65024)	0.073941735884
#   (0, 112984)	0.073941735884
#   (0, 161836)	0.073941735884
#   (0, 179889)	0.073941735884
#   (0, 118386)	0.073941735884
#   (0, 62774)	0.073941735884
#   (0, 102315)	0.073941735884
#   (0, 94049)	0.073941735884
#   (0, 131935)	0.073941735884
#   (0, 141963)	0.073941735884
#   (0, 96679)	0.073941735884
#   (0, 113626)	0.073941735884
#   (0, 164233)	0.073941735884
#   (0, 59253)	0.073941735884
#   (0, 51370)	0.073941735884
#   (0, 35799)	0.073941735884
#   (0, 62760)	0.073941735884
#   :	:
#   (0, 184463)	0.0156508441505
#   (0, 142211)	0.0555654199865
#   (0, 121069)	0.111130839973
#   (0, 37607)	0.0996519817033
#   (0, 40840)	0.105229895418
#   (0, 16503)	0.073941735884
#   (0, 93435)	0.111130839973
#   (0, 25785)	0.0161879311096
#   (0, 7090)	0.0377753217633
#   (0, 99514)	0.0103180497303
#   (0, 162425)	0.0610933773576
#   (0, 47950)	0.0390589971076
#   (0, 174202)	0.039406692004
#   (0, 112781)	0.0610933773576
#   (0, 174238)	0.0180578241282
#   (0, 157413)	0.0374780250871
#   (0, 29512)	0.030818336146
#   (0, 120453)	0.0103388109058
#   (0, 66582)	0.125348698756
#   (0, 51254)	0.161953343898
#   (0, 160345)	0.0102560171793
#   (0, 38866)	0.0508524485219
#   (0, 38887)	0.0508524485219
#   (0, 97713)	0.0498259908516
#   (0, 185398)	0.073941735884

# %%
#Perform LSA using singular value decomposition
lsa = TruncatedSVD(n_components=50, n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=50, n_iter=100,
#        random_state=None, tol=0.0)

# %%
#The first row of matrix V
lsa.components_[0]
# Out:
# array([ 0.00054257,  0.00054257,  0.00054257, ...,  0.00113271,
#         0.00113271,  0.00113271])

# %%
#Print the top 10 terms for each concept
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_):
    termsInComp = zip (terms,comp)
    sortedTerms = sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print("Concept %d:" % i )
    for term in sortedTerms:
        print(term[0])
    print (" ")
# Out:
# Concept 0:
# year
# team
# would
# game
# writes
# cs
# article
# baseball
# players
# games
#
# Concept 1:
# jewish
# come
# baseball
# mets
# baseball players
# good
# reply
# see
# lafayette
# lafibm
#
# Concept 2:
# ibm
# go
# runs
# team
# aix
# baseball
# come
# run
# morris
# mjones
#
# Concept 3:
# team
# morris
# news
# many
# nntp posting
# game
# john
# alomar
# roger
# home
#
# Concept 4:
# clutch
# team
# runs
# 000th career win
# roger
# say
# two
# players
# could
# hit
#
# Concept 5:
# team
# games
# win
# braves
# least
# anyone
# pitching
# look
# baseball
# better
#
# Concept 6:
# first
# win
# know
# game
# games
# may
# runs
# news
# might
# subject
#
# Concept 7:
# would
# even
# games
# player
# go
# time
# pitch
# roger
# run
# alomar
#
# Concept 8:
# year
# say
# back
# mets
# make
# last
# gant
# stats
# hcf jhu
# 000th career win
#
# Concept 9:
# games
# ball
# game
# players
# morris
# good
# well
# time
# lost
# runs
#
# Concept 10:
# world
# first
# baseball
# better
# like
# alomar
# era
# 001 100
# day
# say
#
# Concept 11:
# first
# last
# distribution
# hitter
# writes article
# pitchers
# many
# know
# john
# base
#
# Concept 12:
# two
# still
# go
# nntp
# pitch
# play
# host
# nntp posting
# university
# players
#
# Concept 13:
# time
# one
# last year
# year
# morris
# scott
# alomar
# smith
# play
# article
#
# Concept 14:
# baseball
# good
# hit
# pitcher
# run
# astros
# early
# 001 100
# last year
# thanks
#
# Concept 15:
# university
# posting
# nntp
# think
# players
# games
# going
# better
# writes
# ted
#
# Concept 16:
# pitcher
# john
# one
# university
# years
# ca
# help
# clutch
# jewish
# roger
#
# Concept 17:
# go
# usa
# time
# good
# really
# better
# could
# hitter
# hirschbeck
# career
#
# Concept 18:
# posting
# might
# say
# distribution
# much
# play
# back
# world
# john
# give
#
# Concept 19:
# team
# get
# hit
# posting
# braves
# run
# morris
# pitching
# still
# 1992
#
# Concept 20:
# game
# one
# like
# university
# jays
# players
# last
# first
# might
# best
#
# Concept 21:
# hit
# know
# home
# player
# games
# win
# line
# going
# career
# say
#
# Concept 22:
# braves
# year
# jewish
# hit
# run
# 10
# win
# games
# want
# game
#
# Concept 23:
# nntp posting
# first
# cs
# one
# people
# nntp
# game
# year
# win
# good
#
# Concept 24:
# ca
# 000th career win
# see
# game
# david
# games
# get
# could
# take
# host
#
# Concept 25:
# think
# get
# last
# nntp posting
# year
# like
# see
# runs
# two
# host
#
# Concept 26:
# one
# team
# host
# win
# see
# really
# 001 100
# well
# two
# three
#
# Concept 27:
# jewish
# braves
# players
# year
# new
# think
# home
# hitting
# host
# mets
#
# Concept 28:
# games
# cs
# know
# 000th career win
# one
# would
# see
# even
# john
# left
#
# Concept 29:
# could
# baseball
# would
# day
# may
# pitch
# nntp
# morris
# 12
# stats
#
# Concept 30:
# good
# say
# even
# hit
# year
# day
# would
# runs
# braves
# pitcher
#
# Concept 31:
# year
# pitching
# think
# also
# players
# may
# play
# mets
# roger
# season
#
# Concept 32:
# best
# also
# time
# two
# would
# anyone
# game
# home
# lot
# pitcher
#
# Concept 33:
# way
# hitter
# year
# know
# would
# cs
# season
# organization university
# morris
# take
#
# Concept 34:
# time
# cs
# 000th career win
# hit
# see
# make
# game
# much
# dave
# always
#
# Concept 35:
# year
# baseball
# first
# game
# last
# 0000ahc udcps3 cps
# 001
# writes
# 000th career win
# well
#
# Concept 36:
# time
# like
# think
# posting
# say
# one
# better
# see
# play
# 001 100
#
# Concept 37:
# game
# better
# one
# way
# much
# jewish
# years
# let
# even
# team
#
# Concept 38:
# think
# like
# team
# game
# 001 100
# pitcher
# organization
# could
# also
# last
#
# Concept 39:
# good
# writes
# game
# still
# 001
# organization university
# also
# well
# nntp
# way
#
# Concept 40:
# game
# year
# would
# games
# team
# hit
# subject
# posting
# come
# baseball
#
# Concept 41:
# would
# players
# time
# lines
# year
# 001
# good
# world
# think
# subject
#
# Concept 42:
# think
# university
# game
# 000th
# two
# even
# better
# team
# morris
# last
#
# Concept 43:
# one
# would
# 000th career win
# well
# games
# think
# 000th
# john
# new
# jewish
#
# Concept 44:
# 001 100
# baseball
# runs
# league
# university
# time
# year
# know
# subject
# lines
#
# Concept 45:
# posting
# baseball
# team
# get
# good
# first
# 0000ahc udcps3 cps
# way
# years
# also
#
# Concept 46:
# baseball
# think
# cs
# would
# see
# time
# 000th
# one
# 000th career
# good
#
# Concept 47:
# 000th career win
# 001 100
# good
# would
# win
# organization
# even
# back
# player
# ted
#
# Concept 48:
# last
# 000th career win
# lines
# nntp posting
# 000th
# baseball
# 000th career
# nntp
# nntp posting host
# posting host
#
# Concept 49:
# 000th career
# 0000ahc udcps3 cps
# subject
# 001
# last
# well
# university
# host
# games
# players
